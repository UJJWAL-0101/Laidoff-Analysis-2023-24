# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Layofffs.csv")
data
# Out:
#               Company     Location_HQ        Industry  Percentage        Date  \
# 0              Fisker     Los Angeles  Transportation        0.15  2024-02-29
# 1     Electronic Arts     SF Bay Area        Consumer        0.05  2024-02-28
# 2              Vacasa        Portland          Travel        0.05  2024-02-28
# 3      Treasury Prime     SF Bay Area         Finance        0.40  2024-02-28
# 4            Motional          Boston  Transportation        0.05  2024-02-28
# ...               ...             ...             ...         ...         ...
# 3480          Service     Los Angeles          Travel        1.00  2020-03-16
# 3481     HopSkipDrive     Los Angeles  Transportation        0.10  2020-03-13
# 3482      Panda Squad     SF Bay Area        Consumer        0.75  2020-03-13
# 3483    Tamara Mellon     Los Angeles          Retail        0.40  2020-03-12
# 3484         EasyPost  Salt Lake City       Logistics         NaN  2020-03-11
#
# ...

# %%
data.head().style.set_properties(**{'background-color': '#E1F8FF','color': '#000','border': '1px solid #4AD3FF'})
# Out:
# <style type="text/css">
# ...

# %%
data.describe()
# Out:
#         Percentage   Funds_Raised  Laid_Off_Count
# count  2245.000000    3115.000000     2290.000000
# mean      0.278106     776.946387      250.860699
# std       0.283833    4800.136787      780.128866
# min       0.000000       0.000000        3.000000
# 25%       0.100000      51.000000       40.000000
# 50%       0.170000     165.000000       80.000000
# 75%       0.300000     462.000000      185.750000
# max       1.000000  121900.000000    12000.000000

# %%
data.shape
# Out:
# (3485, 12)

# %%
def get_date():
    year_list = []
    
    col = data['Date_Added']
    for i in range(len(col)):
        date = col[i]
        year = col[i].split("-", 1)[0]
        year_list.append(year)
        # break
    return year_list

layoff_year_list = get_date()

# %%
layoff_year_list
# Out:
# ['2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
# ...

# %%
data['year_of_laidOff'] = layoff_year_list

# %%
data
# Out:
#               Company     Location_HQ        Industry  Percentage        Date  \
# 0              Fisker     Los Angeles  Transportation        0.15  2024-02-29
# 1     Electronic Arts     SF Bay Area        Consumer        0.05  2024-02-28
# 2              Vacasa        Portland          Travel        0.05  2024-02-28
# 3      Treasury Prime     SF Bay Area         Finance        0.40  2024-02-28
# 4            Motional          Boston  Transportation        0.05  2024-02-28
# ...               ...             ...             ...         ...         ...
# 3480          Service     Los Angeles          Travel        1.00  2020-03-16
# 3481     HopSkipDrive     Los Angeles  Transportation        0.10  2020-03-13
# 3482      Panda Squad     SF Bay Area        Consumer        0.75  2020-03-13
# 3483    Tamara Mellon     Los Angeles          Retail        0.40  2020-03-12
# 3484         EasyPost  Salt Lake City       Logistics         NaN  2020-03-11
#
# ...

# %%
data.isnull().sum()
# Out:
# Company                          0
# Location_HQ                      0
# Industry                         0
# Percentage                    1240
# Date                             0
# Source                           0
# Funds_Raised                   370
# Stage                            0
# Date_Added                       0
# Country                          0
# Laid_Off_Count                1195
# List_of_Employees_Laid_Off       1
# year_of_laidOff                  0
# dtype: int64

# %%
data
# Out:
#               Company     Location_HQ        Industry  Percentage        Date  \
# 0              Fisker     Los Angeles  Transportation        0.15  2024-02-29
# 1     Electronic Arts     SF Bay Area        Consumer        0.05  2024-02-28
# 2              Vacasa        Portland          Travel        0.05  2024-02-28
# 3      Treasury Prime     SF Bay Area         Finance        0.40  2024-02-28
# 4            Motional          Boston  Transportation        0.05  2024-02-28
# ...               ...             ...             ...         ...         ...
# 3480          Service     Los Angeles          Travel        1.00  2020-03-16
# 3481     HopSkipDrive     Los Angeles  Transportation        0.10  2020-03-13
# 3482      Panda Squad     SF Bay Area        Consumer        0.75  2020-03-13
# 3483    Tamara Mellon     Los Angeles          Retail        0.40  2020-03-12
# 3484         EasyPost  Salt Lake City       Logistics         NaN  2020-03-11
#
# ...

# %%
data.drop(['Source', 'Date_Added', 'List_of_Employees_Laid_Off'], axis=1, inplace=True)
data
# Out:
#               Company     Location_HQ        Industry  Percentage        Date  \
# 0              Fisker     Los Angeles  Transportation        0.15  2024-02-29
# 1     Electronic Arts     SF Bay Area        Consumer        0.05  2024-02-28
# 2              Vacasa        Portland          Travel        0.05  2024-02-28
# 3      Treasury Prime     SF Bay Area         Finance        0.40  2024-02-28
# 4            Motional          Boston  Transportation        0.05  2024-02-28
# ...               ...             ...             ...         ...         ...
# 3480          Service     Los Angeles          Travel        1.00  2020-03-16
# 3481     HopSkipDrive     Los Angeles  Transportation        0.10  2020-03-13
# 3482      Panda Squad     SF Bay Area        Consumer        0.75  2020-03-13
# 3483    Tamara Mellon     Los Angeles          Retail        0.40  2020-03-12
# 3484         EasyPost  Salt Lake City       Logistics         NaN  2020-03-11
#
# ...

# %%
data.isnull().sum()
# Out:
# Company               0
# Location_HQ           0
# Industry              0
# Percentage         1240
# Date                  0
# Funds_Raised        370
# Stage                 0
# Country               0
# Laid_Off_Count     1195
# year_of_laidOff       0
# dtype: int64

# %%
data = data[data['Laid_Off_Count'].notna()]

# %%
data
# Out:
#                Company     Location_HQ        Industry  Percentage  \
# 1      Electronic Arts     SF Bay Area        Consumer        0.05
# 2               Vacasa        Portland          Travel        0.05
# 3       Treasury Prime     SF Bay Area         Finance        0.40
# 5     Sony Interactive     SF Bay Area        Consumer        0.08
# 6               Bumble          Austin        Consumer        0.30
# ...                ...             ...             ...         ...
# 3479          Help.com          Austin         Support        1.00
# 3481      HopSkipDrive     Los Angeles  Transportation        0.10
# 3482       Panda Squad     SF Bay Area        Consumer        0.75
# 3483     Tamara Mellon     Los Angeles          Retail        0.40
# 3484          EasyPost  Salt Lake City       Logistics         NaN
#
#             Date  Funds_Raised       Stage        Country  Laid_Off_Count  \
# 1     2024-02-28           2.0    Post-IPO  United States           670.0
# ...

# %%
data = data[data['Percentage'].notna()] #drop the rows in column percenage which has NaN

# %%
data
# Out:
#                Company  Location_HQ        Industry  Percentage        Date  \
# 1      Electronic Arts  SF Bay Area        Consumer        0.05  2024-02-28
# 2               Vacasa     Portland          Travel        0.05  2024-02-28
# 3       Treasury Prime  SF Bay Area         Finance        0.40  2024-02-28
# 5     Sony Interactive  SF Bay Area        Consumer        0.08  2024-02-27
# 6               Bumble       Austin        Consumer        0.30  2024-02-27
# ...                ...          ...             ...         ...         ...
# 3478         Inspirato       Denver          Travel        0.22  2020-03-16
# 3479          Help.com       Austin         Support        1.00  2020-03-16
# 3481      HopSkipDrive  Los Angeles  Transportation        0.10  2020-03-13
# 3482       Panda Squad  SF Bay Area        Consumer        0.75  2020-03-13
# 3483     Tamara Mellon  Los Angeles          Retail        0.40  2020-03-12
#
# ...

# %%
laidOff_countYear = data[['year_of_laidOff','Laid_Off_Count']].groupby('year_of_laidOff', as_index=False).sum()
laidOff_countYear #group them according to the year and Laid count
# Out:
#   year_of_laidOff  Laid_Off_Count
# 0            2020         70603.0
# 1            2021          6521.0
# 2            2022        130813.0
# 3            2023        205680.0
# 4            2024         42841.0

# %%
plt.figure(figsize=(50,45))
# plt.plot(marker='o')
plt.plot(laidOff_countYear['year_of_laidOff'], laidOff_countYear['Laid_Off_Count'],color='black',marker='o')
plt.xlabel("Layoff by years")
plt.ylabel("No of layoffs")
plt.show()

# %%
laidOff_countCountry = data[['Country','Laid_Off_Count']].groupby('Country', as_index=False).sum().head()
laidOff_countCountry #group t
# Out:
#      Country  Laid_Off_Count
# 0  Argentina           283.0
# 1  Australia          2946.0
# 2    Austria           340.0
# 3     Brazil          9266.0
# 4   Bulgaria           120.0

# %%
data.shape
# Out:
# (1620, 10)

# %%
data['Company'].head(70)
# Out:
# 1         Electronic Arts
# 2                  Vacasa
# 3          Treasury Prime
# 5        Sony Interactive
# 6                  Bumble
#               ...
# 167       Rent the Runway
# 168    Treasure Financial
# 169                Humane
# 173                 Unity
# 174              Flipkart
# Name: Company, Length: 70, dtype: object

# %%
plt.figure(figsize=(55,45))
plt.rcParams['font.size'] = 40
plt.xticks(rotation = 90)
plt.hist(data['Industry'],bins=31,edgecolor='black',color='skyblue')
plt.xlabel('Industry')
plt.ylabel('Laid Off Count in Percent %')
plt.show()

# %%
laidOff_countCountry = data[['Country','Laid_Off_Count']].groupby('Country', as_index=False).sum()

# %%
laidOff_countCountry
# Out:
#                  Country  Laid_Off_Count
# 0              Argentina           283.0
# 1              Australia          2946.0
# 2                Austria           340.0
# 3                 Brazil          9266.0
# 4               Bulgaria           120.0
# 5                 Canada          8905.0
# 6         Cayman Islands            60.0
# 7                  Chile           295.0
# 8                  China           755.0
# 9         Czech Republic           216.0
# 10               Denmark           185.0
# 11               Estonia           373.0
# 12               Finland           250.0
# 13                France           900.0
# 14               Germany         23200.0
# 15             Hong Kong           730.0
# 16                 India         27522.0
# 17             Indonesia          3071.0
# 18               Ireland           416.0
# 19                Israel          5305.0
# 20                 Kenya           982.0
# 21            Luxembourg            45.0
# ...

# %%
laidOff_countCountry = data[['Company','Laid_Off_Count']].groupby('Company', as_index=False).sum()
laidOff_countCountry
# Out:
#            Company  Laid_Off_Count
# 0            #Paid            19.0
# 1            &Open             9.0
# 2     10X Genomics           100.0
# 3        1K Kirana           600.0
# 4          1stdibs            70.0
# ...            ...             ...
# 1303         iFood           355.0
# 1304  iPrice Group            50.0
# 1305        iRobot           575.0
# 1306         nCino           100.0
# 1307         uShip            65.0
#
# [1308 rows x 2 columns]

# %%
abc=pd.DataFrame(data)

# %%
abc.sort_values('Laid_Off_Count')
# Out:
#          Company    Location_HQ   Industry  Percentage        Date  \
# 2964      Branch  New York City     Retail        0.27  2020-06-11
# 3129  TutorMundi      Sao Paulo  Education        1.00  2020-04-24
# 3477   Flytedesk        Boulder  Marketing        0.20  2020-03-18
# 3255       Spyce         Boston       Food        0.12  2020-04-08
# 2855         Aya        Toronto    Finance        0.25  2020-11-19
# ...          ...            ...        ...         ...         ...
# 1131    Ericsson      Stockholm      Other        0.08  2023-02-24
# 1802      Amazon        Seattle     Retail        0.03  2022-11-16
# 1419   Microsoft        Seattle      Other        0.05  2023-01-18
# 1870        Meta    SF Bay Area   Consumer        0.13  2022-11-09
# 1386      Google    SF Bay Area   Consumer        0.06  2023-01-20
#
#       Funds_Raised     Stage        Country  Laid_Off_Count year_of_laidOff
# 2964           2.0      Seed  United States             3.0            2020
# ...

# %%
data.sort_values('Laid_Off_Count')
# Out:
#          Company    Location_HQ   Industry  Percentage        Date  \
# 2964      Branch  New York City     Retail        0.27  2020-06-11
# 3129  TutorMundi      Sao Paulo  Education        1.00  2020-04-24
# 3477   Flytedesk        Boulder  Marketing        0.20  2020-03-18
# 3255       Spyce         Boston       Food        0.12  2020-04-08
# 2855         Aya        Toronto    Finance        0.25  2020-11-19
# ...          ...            ...        ...         ...         ...
# 1131    Ericsson      Stockholm      Other        0.08  2023-02-24
# 1802      Amazon        Seattle     Retail        0.03  2022-11-16
# 1419   Microsoft        Seattle      Other        0.05  2023-01-18
# 1870        Meta    SF Bay Area   Consumer        0.13  2022-11-09
# 1386      Google    SF Bay Area   Consumer        0.06  2023-01-20
#
#       Funds_Raised     Stage        Country  Laid_Off_Count year_of_laidOff  \
# 2964           2.0      Seed  United States             3.0            2020
# ...

# %%
plt.figure(figsize=(50,45))
plt.rcParams['font.size'] = 40
plt.xticks(rotation=90)
sns.barplot(x='Company', y='Laid_Off_Count', data=data,order=data.sort_values('Laid_Off_Count',ascending = False).Company.head(20))
# sns.barplot(y=laidOff_countCountry['Company'].head(20),x=laidOff_countCountry['Laid_Off_Count'].head(20),orient='h')
plt.show()

# %%
def get_month():
    month_list = []
    
    col = data['Date']
    for date in col:
        parts = date.split("-")
        if len(parts) >= 2:  # Ensure that the date format is valid
            month = parts[1]
            month_list.append(month)
        else:
            print("Invalid date format:", date)
    
    return month_list

layoff_month_list = get_month()

# %%
layoff_month_list
# Out:
# ['02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '12',
#  '11',
#  '11',
#  '11',
#  '11',
#  '11',
#  '11',
#  '11',
#  '11',
#  '11',
#  '11',
#  '11',
#  '11',
#  '11',
#  '11',
#  '11',
#  '10',
# ...

# %%
data['month_layoff'] = layoff_month_list
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_15824\735174443.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['month_layoff'] = layoff_month_list

# %%
data
# Out:
#                Company  Location_HQ        Industry  Percentage        Date  \
# 1      Electronic Arts  SF Bay Area        Consumer        0.05  2024-02-28
# 2               Vacasa     Portland          Travel        0.05  2024-02-28
# 3       Treasury Prime  SF Bay Area         Finance        0.40  2024-02-28
# 5     Sony Interactive  SF Bay Area        Consumer        0.08  2024-02-27
# 6               Bumble       Austin        Consumer        0.30  2024-02-27
# ...                ...          ...             ...         ...         ...
# 3478         Inspirato       Denver          Travel        0.22  2020-03-16
# 3479          Help.com       Austin         Support        1.00  2020-03-16
# 3481      HopSkipDrive  Los Angeles  Transportation        0.10  2020-03-13
# 3482       Panda Squad  SF Bay Area        Consumer        0.75  2020-03-13
# 3483     Tamara Mellon  Los Angeles          Retail        0.40  2020-03-12
#
# ...

# %%
layoff_month = data[['month_layoff','Laid_Off_Count']].groupby('month_layoff', as_index=False).sum()
layoff_month
# Out:
#    month_layoff  Laid_Off_Count
# 0            01        112071.0
# 1            02         52059.0
# 2            03         22950.0
# 3            04         43271.0
# 4            05         48977.0
# 5            06         31235.0
# 6            07         23755.0
# 7            08         21027.0
# 8            09          7075.0
# 9            10         24674.0
# 10           11         55509.0
# 11           12         13855.0

# %%
plt.figure(figsize=(50,45))
plt.pie(labels=layoff_month['month_layoff'],x=layoff_month['Laid_Off_Count'],autopct='%.2f')
plt.title('Laid Off in Months')
plt.legend()
plt.show()
